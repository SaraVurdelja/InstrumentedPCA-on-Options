# %% [markdown]
# # InstrumentedPCA - Puts
# - 20 Factors considered
# - Features are aligned with all information being available at time t
# - Unrestricted model: intercept is included
# - Includes minor preprocessing, datasets saving and statistical tests

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score
from scipy.stats import chi2
from ipca import InstrumentedPCA

# %%
puts = pd.read_csv('SPX_Processed_IPCA_puts_Trimmed.csv')
puts.drop(['call_payoff'], axis=1, inplace=True)
puts.dropna(inplace=True)
puts.rename(columns={'Unnamed: 0': 'temp_ID'}, inplace=True)
puts.drop(['option_type', 'best_ask', 'best_bid', 'best_bid_size', 'best_ask_size', 'expiration'], axis=1, inplace=True)
puts.columns
# Out:
# Index(['temp_ID', 'date', 'strike_price', 'spot_price', 'forward_price', 'vix',
#        'div_yield', 'risk_free', 'time_to_maturity_OPT', 'moneyness',
#        'option_price', 'bidask_spread', 'effective_spread', 'vwap', 'volume',
#        'open_interest', 'impl_volatility', 'delta', 'gamma', 'vega', 'theta',
#        'rho', 'vanna', 'charm', 'vomma', 'zomma', 'color', 'dvega_dtime',
#        'return', 'his_volatility', 'realised_skewness', 'realised_kurtosis',
#        'model_free_iv', 'model_free_skew', 'model_free_kurt', 'rv_iv',
#        'rv_mfvol', 'rskew_mfskew', 'rkurt_mfkurt', 'put_payoff'],
#       dtype='object')

# %%
# Monthly panels
puts['date'] = pd.to_datetime(puts['date'])
puts['month'] = puts['date'].dt.to_period('M').dt.to_timestamp().astype('int64') // 10**9

# Unique identifier based on strike and maturity to respect parity conditions
puts['unique_id'] = (puts['strike_price'].astype(str) + '_' + 
                      puts['time_to_maturity_OPT'].astype(str))

# Converting to a numeric ID
unique_ids = np.unique(puts['unique_id'])
ID_map = dict(zip(unique_ids, np.arange(1, len(unique_ids) + 1)))
puts['unique_id'] = puts['unique_id'].apply(lambda x: ID_map[x])

# MultiIndex with ID and monthly panel
puts.set_index(['unique_id', 'month'], inplace=True)

# Splitting into testing and training
max_year = puts['date'].max().year
train_data = puts[puts['date'].dt.year < (max_year - 2)]
test_data = puts[puts['date'].dt.year >= (max_year - 2)]

# Training data
X_train = train_data.drop(['put_payoff', 'date', 'temp_ID'], axis=1).select_dtypes(include=[np.number])
y_train = train_data['put_payoff']

# Testing data (stable economic conditions)
X_test = test_data.drop(['put_payoff', 'date', 'temp_ID'], axis=1).select_dtypes(include=[np.number])
y_test = test_data['put_payoff']

# Normalisation
means = X_train.mean()
stds = X_train.std()
X_train_scaled = (X_train - means) / stds
X_train = pd.DataFrame(X_train_scaled, index=X_train.index, columns=X_train.columns)
X_test_scaled = (X_test - means) / stds
X_test = pd.DataFrame(X_test_scaled, index=X_test.index, columns=X_test.columns)

# Panel indices
train_indices = np.array([X_train.index.get_level_values(0), X_train.index.get_level_values(1)]).T
test_indices = np.array([X_test.index.get_level_values(0), X_test.index.get_level_values(1)]).T

# Fitting IPCA with intercept (unrestricted model)
ipca = InstrumentedPCA(n_factors=5, intercept=True)
ipca.fit(X=X_train, y=y_train, indices=train_indices)
Gamma, Factors = ipca.get_factors(label_ind=True)
# Out:
# [======                                                                  ]   8%
# The panel dimensions are:
# Step 9979 - Aggregate Update: 115.24173767232584
# Step 9980 - Aggregate Update: 91.87451533893079
# Step 9981 - Aggregate Update: 109.90888563634178
# Step 9982 - Aggregate Update: 42.46714464407521
# Step 9983 - Aggregate Update: 34.35587697024556
# Step 9984 - Aggregate Update: 12.037837240210145
# Step 9985 - Aggregate Update: 11.356844265730267
# Step 9986 - Aggregate Update: 8.698587055207371
# Step 9987 - Aggregate Update: 11.963087007575751
# Step 9988 - Aggregate Update: 25.101319028817045
# Step 9989 - Aggregate Update: 50.97980752568826
# Step 9990 - Aggregate Update: 123.18115574618312
# Step 9991 - Aggregate Update: 76.80858952558017
# Step 9992 - Aggregate Update: 40.09385286616791
# Step 9993 - Aggregate Update: 92.37368355664293
# Step 9994 - Aggregate Update: 76.78146726292023
# Step 9995 - Aggregate Update: 38.031196290111666
# Step 9996 - Aggregate Update: 43.878839420467024
# Step 9997 - Aggregate Update: 39.79360625466476
# Step 9998 - Aggregate Update: 10.370670088152588
# Step 9999 - Aggregate Update: 21.378903833200102
# Step 10000 - Aggregate Update: 17.024257074356658
# Step 10001 - Aggregate Update: 45.863389324133266
# -- Convergence Reached --

# %% [markdown]
# ## Evaluation Metrics & Residuals

# %%
# In-sample R²
r2_train = ipca.score(X=X_train, y=y_train, indices=train_indices)

# Out of sample predictions
y_test_pred = ipca.predictOOS(X=X_test, y = y_test, mean_factor=True)
# R² Pred
r2_pred = r2_score(y_test, y_test_pred)

print(f"R² (train): {r2_train}")
print(f"R² Pred (test): {r2_pred}")
# Out:
# R² (train): 0.08475641679678958
# R² Pred (test): -2.930528480097331

# %%
# Residuals for the test set
residuals_test = y_test - y_test_pred
y_train_pred = ipca.predictOOS(X=X_train, y = y_train, mean_factor=True)

# Residuals for the training set
residuals_train = y_train - y_train_pred

# %%
# y_test vs y_test_pred
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_test_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='black', linestyle='--')
plt.xlabel('Test Set True Values')
plt.ylabel('Predicted Values')
plt.title('Test Set True vs Predicted Values - IPCA5 Puts')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Wald Test for Coefficients Significance

# %%
Gamma = Gamma.values  # numpy array

# Covariance matrix of the factor loadings across the characteristics
Gamma_cov = np.cov(Gamma.T)

# Wald Test Function
def wald_test_matrix(Gamma, Gamma_cov):
    results = []
    num_loadings = Gamma.shape[0]  # 37 characteristics
    num_factors = Gamma.shape[1]  # 21 factors (20 + intercept)

    for i in range(num_loadings):
        Gamma_i = Gamma[i, :]
        wald_stat = np.dot(np.dot(Gamma_i.T, np.linalg.inv(Gamma_cov)), Gamma_i)
        df = num_factors
        p_value = 1 - chi2.cdf(wald_stat, df)
        results.append((wald_stat, p_value, "Significant" if p_value < 0.05 else "Not Significant"))

    return results

# Running the Wald test
wald_results = wald_test_matrix(Gamma, Gamma_cov)
for i, (wald_stat, p_value, significance) in enumerate(wald_results):
    print(f"Characteristic {i+1}: Wald Statistic: {wald_stat:.4f}, P-value: {p_value:.4f}, Result: {significance}")

# %% [markdown]
# ### Confidence Intervals for Coefficients Significance

# %%
# Variance of residuals
residual_variance = np.var(residuals_train, ddof=1)  # sample variance

# Matrix to store the standard errors
std_errors_gamma = np.zeros(Gamma.shape)
for i in range(Gamma.shape[0]):  # For each characteristic (row in Gamma)
    for j in range(Gamma.shape[1]):  # For each factor (column in Gamma)
        std_errors_gamma[i, j] = np.sqrt(residual_variance / np.sum(X_train.iloc[:, j] ** 2))

# Confidence level alpha 5%
z_value = 1.96

# Confidence intervals for each loading
lower_bounds_gamma = Gamma - z_value * std_errors_gamma
upper_bounds_gamma = Gamma + z_value * std_errors_gamma

# Checking significance based on whether the CI includes zero
significant_loadings = (lower_bounds_gamma > 0) | (upper_bounds_gamma < 0)

# Arrays
significant_loadings = significant_loadings.values if isinstance(significant_loadings, pd.DataFrame) else significant_loadings
lower_bounds_gamma = lower_bounds_gamma.values if isinstance(lower_bounds_gamma, pd.DataFrame) else lower_bounds_gamma
upper_bounds_gamma = upper_bounds_gamma.values if isinstance(upper_bounds_gamma, pd.DataFrame) else upper_bounds_gamma

# Print check
for i in range(Gamma.shape[0]):  # For each characteristic
    for j in range(Gamma.shape[1]):  # For each factor
        is_significant = "Significant" if significant_loadings[i, j] else "Not Significant"
        print(f"Characteristic {i+1}, Factor {j+1}: CI = [{lower_bounds_gamma[i, j]:.4f}, {upper_bounds_gamma[i, j]:.4f}], {is_significant}")
# Out:
# Characteristic 1, Factor 1: CI = [-0.0897, 0.0895], Not Significant
# Characteristic 1, Factor 2: CI = [-0.0889, 0.0903], Not Significant
# Characteristic 1, Factor 3: CI = [-0.0914, 0.0877], Not Significant
# Characteristic 1, Factor 4: CI = [-0.0862, 0.0930], Not Significant
# Characteristic 1, Factor 5: CI = [-0.0429, 0.1363], Not Significant
# Characteristic 1, Factor 6: CI = [8.7441, 8.9233], Significant
# Characteristic 2, Factor 1: CI = [-0.0966, 0.0826], Not Significant
# Characteristic 2, Factor 2: CI = [-0.0977, 0.0815], Not Significant
# Characteristic 2, Factor 3: CI = [-0.0828, 0.0963], Not Significant
# Characteristic 2, Factor 4: CI = [-0.0458, 0.1334], Not Significant
# Characteristic 2, Factor 5: CI = [0.2503, 0.4294], Significant
# Characteristic 2, Factor 6: CI = [54.6884, 54.8676], Significant
# Characteristic 3, Factor 1: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 3, Factor 2: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 3, Factor 3: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 3, Factor 4: CI = [-0.0889, 0.0903], Not Significant
# Characteristic 3, Factor 5: CI = [-0.0910, 0.0882], Not Significant
# Characteristic 3, Factor 6: CI = [-0.3035, -0.1244], Significant
# Characteristic 4, Factor 1: CI = [-0.0910, 0.0882], Not Significant
# Characteristic 4, Factor 2: CI = [-0.0910, 0.0881], Not Significant
# Characteristic 4, Factor 3: CI = [-0.0880, 0.0912], Not Significant
# Characteristic 4, Factor 4: CI = [-0.0617, 0.1175], Not Significant
# Characteristic 4, Factor 5: CI = [0.0920, 0.2712], Significant
# Characteristic 4, Factor 6: CI = [20.5469, 20.7261], Significant
# Characteristic 5, Factor 1: CI = [-0.0897, 0.0895], Not Significant
# Characteristic 5, Factor 2: CI = [-0.0894, 0.0898], Not Significant
# Characteristic 5, Factor 3: CI = [-0.0894, 0.0897], Not Significant
# Characteristic 5, Factor 4: CI = [-0.0849, 0.0943], Not Significant
# Characteristic 5, Factor 5: CI = [-0.0878, 0.0914], Not Significant
# Characteristic 5, Factor 6: CI = [-0.6584, -0.4792], Significant
# Characteristic 6, Factor 1: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 6, Factor 2: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 6, Factor 3: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 6, Factor 4: CI = [-0.0902, 0.0889], Not Significant
# Characteristic 6, Factor 5: CI = [-0.0882, 0.0909], Not Significant
# Characteristic 6, Factor 6: CI = [-0.0619, 0.1173], Not Significant
# Characteristic 7, Factor 1: CI = [-0.0897, 0.0895], Not Significant
# Characteristic 7, Factor 2: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 7, Factor 3: CI = [-0.0879, 0.0912], Not Significant
# Characteristic 7, Factor 4: CI = [-0.0916, 0.0875], Not Significant
# Characteristic 7, Factor 5: CI = [-0.1601, 0.0190], Not Significant
# Characteristic 7, Factor 6: CI = [-5.0999, -4.9208], Significant
# Characteristic 8, Factor 1: CI = [-0.0896, 0.0895], Not Significant
# Characteristic 8, Factor 2: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 8, Factor 3: CI = [-0.0897, 0.0895], Not Significant
# Characteristic 8, Factor 4: CI = [-0.0949, 0.0843], Not Significant
# Characteristic 8, Factor 5: CI = [-0.0697, 0.1094], Not Significant
# Characteristic 8, Factor 6: CI = [0.8259, 1.0051], Significant
# Characteristic 9, Factor 1: CI = [-0.5928, -0.4136], Significant
# Characteristic 9, Factor 2: CI = [-0.3769, -0.1977], Significant
# Characteristic 9, Factor 3: CI = [0.2826, 0.4618], Significant
# Characteristic 9, Factor 4: CI = [0.0757, 0.2549], Significant
# Characteristic 9, Factor 5: CI = [-0.0169, 0.1623], Not Significant
# Characteristic 9, Factor 6: CI = [43.5745, 43.7536], Significant
# Characteristic 10, Factor 1: CI = [-0.0891, 0.0901], Not Significant
# Characteristic 10, Factor 2: CI = [-0.0897, 0.0895], Not Significant
# Characteristic 10, Factor 3: CI = [-0.0887, 0.0905], Not Significant
# Characteristic 10, Factor 4: CI = [-0.0610, 0.1182], Not Significant
# Characteristic 10, Factor 5: CI = [-0.0953, 0.0839], Not Significant
# Characteristic 10, Factor 6: CI = [1.6491, 1.8283], Significant
# Characteristic 11, Factor 1: CI = [-0.0898, 0.0893], Not Significant
# Characteristic 11, Factor 2: CI = [-0.0900, 0.0892], Not Significant
# Characteristic 11, Factor 3: CI = [-0.0907, 0.0885], Not Significant
# Characteristic 11, Factor 4: CI = [-0.1034, 0.0758], Not Significant
# Characteristic 11, Factor 5: CI = [-0.1171, 0.0621], Not Significant
# Characteristic 11, Factor 6: CI = [-4.7852, -4.6060], Significant
# Characteristic 12, Factor 1: CI = [0.4152, 0.5943], Significant
# Characteristic 12, Factor 2: CI = [0.2011, 0.3802], Significant
# Characteristic 12, Factor 3: CI = [-0.4551, -0.2759], Significant
# Characteristic 12, Factor 4: CI = [-0.2017, -0.0225], Significant
# Characteristic 12, Factor 5: CI = [0.1431, 0.3223], Significant
# Characteristic 12, Factor 6: CI = [38.6581, 38.8372], Significant
# Characteristic 13, Factor 1: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 13, Factor 2: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 13, Factor 3: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 13, Factor 4: CI = [-0.0906, 0.0886], Not Significant
# Characteristic 13, Factor 5: CI = [-0.0879, 0.0913], Not Significant
# Characteristic 13, Factor 6: CI = [-0.4273, -0.2481], Significant
# Characteristic 14, Factor 1: CI = [-0.0896, 0.0895], Not Significant
# Characteristic 14, Factor 2: CI = [-0.0896, 0.0895], Not Significant
# Characteristic 14, Factor 3: CI = [-0.0895, 0.0896], Not Significant
# Characteristic 14, Factor 4: CI = [-0.0903, 0.0889], Not Significant
# Characteristic 14, Factor 5: CI = [-0.0937, 0.0855], Not Significant
# Characteristic 14, Factor 6: CI = [-0.1629, 0.0162], Not Significant
# Characteristic 15, Factor 1: CI = [0.1342, 0.3134], Significant
# Characteristic 15, Factor 2: CI = [0.2215, 0.4006], Significant
# Characteristic 15, Factor 3: CI = [0.4402, 0.6194], Significant
# Characteristic 15, Factor 4: CI = [-0.0828, 0.0963], Not Significant
# Characteristic 15, Factor 5: CI = [-0.1631, 0.0160], Not Significant
# Characteristic 15, Factor 6: CI = [7.0140, 7.1931], Significant
# Characteristic 16, Factor 1: CI = [-0.0886, 0.0905], Not Significant
# Characteristic 16, Factor 2: CI = [-0.0886, 0.0905], Not Significant
# Characteristic 16, Factor 3: CI = [-0.0875, 0.0916], Not Significant
# Characteristic 16, Factor 4: CI = [-0.0569, 0.1222], Not Significant
# Characteristic 16, Factor 5: CI = [0.0413, 0.2205], Significant
# Characteristic 16, Factor 6: CI = [13.7696, 13.9487], Significant
# Characteristic 17, Factor 1: CI = [-0.0893, 0.0899], Not Significant
# Characteristic 17, Factor 2: CI = [-0.0891, 0.0901], Not Significant
# Characteristic 17, Factor 3: CI = [-0.0881, 0.0910], Not Significant
# Characteristic 17, Factor 4: CI = [-0.0873, 0.0918], Not Significant
# Characteristic 17, Factor 5: CI = [-0.0342, 0.1449], Not Significant
# Characteristic 17, Factor 6: CI = [3.2123, 3.3915], Significant
# Characteristic 18, Factor 1: CI = [-0.0905, 0.0887], Not Significant
# Characteristic 18, Factor 2: CI = [-0.0950, 0.0842], Not Significant
# Characteristic 18, Factor 3: CI = [-0.0815, 0.0976], Not Significant
# Characteristic 18, Factor 4: CI = [-0.3093, -0.1301], Significant
# Characteristic 18, Factor 5: CI = [-0.3183, -0.1391], Significant
# Characteristic 18, Factor 6: CI = [-72.5045, -72.3253], Significant
# Characteristic 19, Factor 1: CI = [-0.0894, 0.0897], Not Significant
# Characteristic 19, Factor 2: CI = [-0.0889, 0.0902], Not Significant
# Characteristic 19, Factor 3: CI = [-0.0885, 0.0907], Not Significant
# Characteristic 19, Factor 4: CI = [-0.0823, 0.0969], Not Significant
# Characteristic 19, Factor 5: CI = [-0.0635, 0.1157], Not Significant
# Characteristic 19, Factor 6: CI = [1.7313, 1.9104], Significant
# Characteristic 20, Factor 1: CI = [-0.0888, 0.0903], Not Significant
# Characteristic 20, Factor 2: CI = [-0.0914, 0.0877], Not Significant
# Characteristic 20, Factor 3: CI = [-0.0844, 0.0948], Not Significant
# Characteristic 20, Factor 4: CI = [-0.1107, 0.0684], Not Significant
# Characteristic 20, Factor 5: CI = [-0.2054, -0.0263], Significant
# Characteristic 20, Factor 6: CI = [-15.5523, -15.3732], Significant
# Characteristic 21, Factor 1: CI = [-0.0894, 0.0898], Not Significant
# Characteristic 21, Factor 2: CI = [-0.0892, 0.0900], Not Significant
# Characteristic 21, Factor 3: CI = [-0.0901, 0.0890], Not Significant
# Characteristic 21, Factor 4: CI = [-0.0721, 0.1070], Not Significant
# Characteristic 21, Factor 5: CI = [-0.0609, 0.1182], Not Significant
# Characteristic 21, Factor 6: CI = [6.2688, 6.4480], Significant
# Characteristic 22, Factor 1: CI = [-0.0895, 0.0897], Not Significant
# Characteristic 22, Factor 2: CI = [-0.0895, 0.0897], Not Significant
# Characteristic 22, Factor 3: CI = [-0.0898, 0.0894], Not Significant
# Characteristic 22, Factor 4: CI = [-0.0844, 0.0948], Not Significant
# Characteristic 22, Factor 5: CI = [-0.0882, 0.0909], Not Significant
# Characteristic 22, Factor 6: CI = [1.0181, 1.1973], Significant
# Characteristic 23, Factor 1: CI = [-0.0906, 0.0886], Not Significant
# Characteristic 23, Factor 2: CI = [-0.0896, 0.0896], Not Significant
# Characteristic 23, Factor 3: CI = [-0.0869, 0.0922], Not Significant
# Characteristic 23, Factor 4: CI = [-0.1262, 0.0530], Not Significant
# Characteristic 23, Factor 5: CI = [-0.2005, -0.0213], Significant
# Characteristic 23, Factor 6: CI = [-17.2193, -17.0402], Significant
# Characteristic 24, Factor 1: CI = [-0.0887, 0.0904], Not Significant
# Characteristic 24, Factor 2: CI = [-0.0890, 0.0902], Not Significant
# Characteristic 24, Factor 3: CI = [-0.0920, 0.0872], Not Significant
# Characteristic 24, Factor 4: CI = [-0.0409, 0.1382], Not Significant
# Characteristic 24, Factor 5: CI = [0.0167, 0.1958], Significant
# Characteristic 24, Factor 6: CI = [18.2760, 18.4551], Significant
# Characteristic 25, Factor 1: CI = [-0.0895, 0.0896], Not Significant
# Characteristic 25, Factor 2: CI = [-0.0894, 0.0898], Not Significant
# Characteristic 25, Factor 3: CI = [-0.0891, 0.0900], Not Significant
# Characteristic 25, Factor 4: CI = [-0.0885, 0.0906], Not Significant
# Characteristic 25, Factor 5: CI = [-0.0728, 0.1063], Not Significant
# Characteristic 25, Factor 6: CI = [2.3592, 2.5384], Significant
# Characteristic 26, Factor 1: CI = [-0.0896, 0.0895], Not Significant
# Characteristic 26, Factor 2: CI = [-0.0902, 0.0890], Not Significant
# Characteristic 26, Factor 3: CI = [-0.0893, 0.0899], Not Significant
# Characteristic 26, Factor 4: CI = [-0.1039, 0.0752], Not Significant
# Characteristic 26, Factor 5: CI = [-0.1139, 0.0653], Not Significant
# Characteristic 26, Factor 6: CI = [-5.9424, -5.7632], Significant
# Characteristic 27, Factor 1: CI = [-0.0895, 0.0896], Not Significant
# Characteristic 27, Factor 2: CI = [-0.0895, 0.0897], Not Significant
# Characteristic 27, Factor 3: CI = [-0.0893, 0.0899], Not Significant
# Characteristic 27, Factor 4: CI = [-0.0867, 0.0925], Not Significant
# Characteristic 27, Factor 5: CI = [-0.0766, 0.1026], Not Significant
# Characteristic 27, Factor 6: CI = [1.1478, 1.3269], Significant
# Characteristic 28, Factor 1: CI = [-0.1671, 0.0121], Not Significant
# Characteristic 28, Factor 2: CI = [-0.2002, -0.0211], Significant
# Characteristic 28, Factor 3: CI = [-0.2752, -0.0960], Significant
# Characteristic 28, Factor 4: CI = [-0.0874, 0.0918], Not Significant
# Characteristic 28, Factor 5: CI = [-0.0625, 0.1167], Not Significant
# Characteristic 28, Factor 6: CI = [-2.3139, -2.1347], Significant
# Characteristic 29, Factor 1: CI = [-0.0891, 0.0901], Not Significant
# Characteristic 29, Factor 2: CI = [-0.0892, 0.0900], Not Significant
# Characteristic 29, Factor 3: CI = [-0.0866, 0.0926], Not Significant
# Characteristic 29, Factor 4: CI = [-0.0637, 0.1155], Not Significant
# Characteristic 29, Factor 5: CI = [-0.0658, 0.1134], Not Significant
# Characteristic 29, Factor 6: CI = [2.6275, 2.8067], Significant
# Characteristic 30, Factor 1: CI = [-0.0891, 0.0901], Not Significant
# Characteristic 30, Factor 2: CI = [-0.0889, 0.0903], Not Significant
# Characteristic 30, Factor 3: CI = [-0.0886, 0.0906], Not Significant
# Characteristic 30, Factor 4: CI = [-0.0886, 0.0906], Not Significant
# Characteristic 30, Factor 5: CI = [-0.0940, 0.0851], Not Significant
# Characteristic 30, Factor 6: CI = [-1.9053, -1.7261], Significant
# Characteristic 31, Factor 1: CI = [-0.5134, -0.3342], Significant
# Characteristic 31, Factor 2: CI = [0.4497, 0.6289], Significant
# Characteristic 31, Factor 3: CI = [-0.2062, -0.0270], Significant
# Characteristic 31, Factor 4: CI = [-0.1250, 0.0541], Not Significant
# Characteristic 31, Factor 5: CI = [0.0045, 0.1836], Significant
# Characteristic 31, Factor 6: CI = [-9.8729, -9.6937], Significant
# Characteristic 32, Factor 1: CI = [-0.1126, 0.0666], Not Significant
# Characteristic 32, Factor 2: CI = [-0.2094, -0.0302], Significant
# Characteristic 32, Factor 3: CI = [0.0730, 0.2522], Significant
# Characteristic 32, Factor 4: CI = [-0.5627, -0.3835], Significant
# Characteristic 32, Factor 5: CI = [0.3438, 0.5230], Significant
# Characteristic 32, Factor 6: CI = [-24.0622, -23.8831], Significant
# Characteristic 33, Factor 1: CI = [0.0019, 0.1811], Significant
# Characteristic 33, Factor 2: CI = [-0.0857, 0.0935], Not Significant
# Characteristic 33, Factor 3: CI = [-0.0441, 0.1350], Not Significant
# Characteristic 33, Factor 4: CI = [0.3854, 0.5646], Significant
# Characteristic 33, Factor 5: CI = [0.2723, 0.4515], Significant
# Characteristic 33, Factor 6: CI = [-50.5084, -50.3292], Significant
# Characteristic 34, Factor 1: CI = [0.1528, 0.3319], Significant
# Characteristic 34, Factor 2: CI = [0.2469, 0.4261], Significant
# Characteristic 34, Factor 3: CI = [0.4833, 0.6624], Significant
# Characteristic 34, Factor 4: CI = [-0.0927, 0.0865], Not Significant
# Characteristic 34, Factor 5: CI = [-0.1732, 0.0059], Not Significant
# Characteristic 34, Factor 6: CI = [7.7074, 7.8866], Significant
# Characteristic 35, Factor 1: CI = [-0.5136, -0.3344], Significant
# Characteristic 35, Factor 2: CI = [0.4499, 0.6291], Significant
# Characteristic 35, Factor 3: CI = [-0.2070, -0.0278], Significant
# Characteristic 35, Factor 4: CI = [-0.1261, 0.0531], Not Significant
# Characteristic 35, Factor 5: CI = [0.0195, 0.1986], Significant
# Characteristic 35, Factor 6: CI = [-7.2499, -7.0708], Significant
# Characteristic 36, Factor 1: CI = [-0.1126, 0.0666], Not Significant
# Characteristic 36, Factor 2: CI = [-0.2094, -0.0303], Significant
# Characteristic 36, Factor 3: CI = [0.0730, 0.2522], Significant
# Characteristic 36, Factor 4: CI = [-0.5629, -0.3837], Significant
# Characteristic 36, Factor 5: CI = [0.3440, 0.5232], Significant
# Characteristic 36, Factor 6: CI = [-24.1158, -23.9366], Significant
# Characteristic 37, Factor 1: CI = [0.0019, 0.1811], Significant
# Characteristic 37, Factor 2: CI = [-0.0856, 0.0935], Not Significant
# Characteristic 37, Factor 3: CI = [-0.0442, 0.1350], Not Significant
# Characteristic 37, Factor 4: CI = [0.3853, 0.5644], Significant
# Characteristic 37, Factor 5: CI = [0.2715, 0.4507], Significant
# Characteristic 37, Factor 6: CI = [-50.4072, -50.2280], Significant

# %% [markdown]
# ### Scree Plot & Gamma-Factors Loadings

# %%
correlation_matrix = np.corrcoef(X_train.T)  # correlation between characteristics
eigenvalues, _ = np.linalg.eig(correlation_matrix)
sorted_eigenvalues = np.sort(eigenvalues)[::-1]

# Scree plot
plt.plot(sorted_eigenvalues)
plt.title("Scree Plot - IPCA Puts")
plt.xlabel("Factors")
plt.ylabel("Eigenvalues")
plt.show()

# %%
# Gamma loadings for each factor - IPCA5 Puts
for factor in Gamma.columns:
    plt.figure(figsize=(14, 8))
    plt.bar(Gamma.index, Gamma[factor], color='skyblue', edgecolor='black')
    plt.axhline(0, color='black', linewidth=1)
    plt.title(f'Gamma Loadings for Factor {factor} - IPCA5 Puts\', fontsize=16)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Covid Test Set
# - Covid testing set from 01/01/2020 to 28/02/2023
# - Features are engineered following the same process executed in the notebook "SPX_Preprocessing_DASK"

# %%
covid_puts = pd.read_csv('IPCA_Puts_Stress_Test.csv')
covid_puts.drop(['call_payoff'], axis=1, inplace=True)
covid_puts.dropna(inplace=True)
covid_puts.rename(columns={'Unnamed: 0': 'temp_ID'}, inplace=True)
covid_puts.drop(['option_type', 'best_ask', 'best_bid', 'best_bid_size', 'best_ask_size', 'expiration'], axis=1, inplace=True)
covid_puts.columns
# Out:
# Index(['temp_ID', 'date', 'strike_price', 'spot_price', 'forward_price', 'vix',
#        'div_yield', 'risk_free', 'time_to_maturity_OPT', 'moneyness',
#        'option_price', 'bidask_spread', 'effective_spread', 'vwap', 'volume',
#        'open_interest', 'impl_volatility', 'delta', 'gamma', 'vega', 'theta',
#        'rho', 'vanna', 'charm', 'vomma', 'zomma', 'color', 'dvega_dtime',
#        'return', 'his_volatility', 'realised_skewness', 'realised_kurtosis',
#        'model_free_iv', 'model_free_skew', 'model_free_kurt', 'rv_iv',
#        'rv_mfvol', 'rskew_mfskew', 'rkurt_mfkurt', 'put_payoff'],
#       dtype='object')

# %%
# Monthly panels
covid_puts['date'] = pd.to_datetime(covid_puts['date'])
covid_puts['month'] = covid_puts['date'].dt.to_period('M').dt.to_timestamp().astype('int64') // 10**9

# Unique identifier based on strike and maturity to respect parity conditions
covid_puts['unique_id'] = (covid_puts['strike_price'].astype(str) + '_' + 
                      covid_puts['time_to_maturity_OPT'].astype(str))

# Converting to a numeric ID
unique_ids = np.unique(covid_puts['unique_id'])
ID_map = dict(zip(unique_ids, np.arange(1, len(unique_ids) + 1)))
covid_puts['unique_id'] = covid_puts['unique_id'].apply(lambda x: ID_map[x])
covid_puts.set_index(['unique_id', 'month'], inplace=True)

# Covid testing set
X_test_covid = covid_puts.drop(['put_payoff', 'date', 'temp_ID'], axis=1).select_dtypes(include=[np.number])
y_test_covid = covid_puts['put_payoff']

# Normalisation
X_test_scaled = (X_test_covid - means) / stds
X_test_covid = pd.DataFrame(X_test_scaled, index=X_test_covid.index, columns=X_test_covid.columns)

# %%
covid_test_indices = np.array([X_test_covid.index.get_level_values(0), X_test_covid.index.get_level_values(1)]).T

# Out of sample predictions on Covid set
y_test_pred_covid = ipca.predictOOS(X=X_test_covid, y=y_test_covid, indices=covid_test_indices, mean_factor=True)
r2_pred = r2_score(y_test_covid, y_test_pred_covid)
print(f"R² Pred (test): {r2_pred}")
# Out:
# R² Pred (test): -3.265333888801984

# %%
# y_test_covid vs y_test_pred_covid
plt.figure(figsize=(10, 6))
plt.scatter(y_test_covid, y_test_pred_covid, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='black', linestyle='--')
plt.xlabel('Covid Set True Values')
plt.ylabel('Predicted Values')
plt.title('Covid Set True vs Predicted Values - IPCA5 Puts')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Saving intermediate datasets for prediction modelling

# %%
# Saving test data IPCA 20 Factors Calls
test_data[['date', 'put_payoff', 'spot_price', 'strike_price', 'time_to_maturity_OPT', 'risk_free', 'impl_volatility']].to_csv('Test_Puts5.csv')

# %%
# Merging real test Covid and prediction values
y_test = y_test.to_numpy()
df = pd.DataFrame({'True': y_test, 'Predicted': y_test_pred})
df.to_csv('IPCA_Puts_Predictions_Test5.csv')

# %%
# Saving Covid test data IPCA 20 Factors Puts
covid_puts[['date', 'put_payoff', 'spot_price', 'strike_price', 'time_to_maturity_OPT', 'risk_free', 'impl_volatility']].to_csv('Covid_Puts5.csv')

# %%
# Merging real Covid test and prediction values
y_test_covid = y_test_covid.to_numpy()
df = pd.DataFrame({'True': y_test_covid, 'Predicted': y_test_pred_covid})
df.to_csv('IPCA_Puts_Predictions_Covid5.csv')
