# %% [markdown]
# # InstrumentedPCA - Calls
# - 20 Factors considered
# - Features are aligned with all information being available at time t
# - Unrestricted model: intercept is included
# - Includes minor preprocessing, datasets saving and statistical tests

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score
from scipy.stats import chi2
from ipca import InstrumentedPCA

# %%
calls = pd.read_csv('SPX_Processed_IPCA_calls_Trimmed.csv')
calls.drop(['put_payoff'], axis=1, inplace=True)
calls.dropna(inplace=True)
calls.rename(columns={'Unnamed: 0': 'temp_ID'}, inplace=True)
calls.drop(['option_type', 'best_ask', 'best_bid', 'best_bid_size', 'best_ask_size', 'expiration'], axis=1, inplace=True)
calls.columns
# Out:
# Index(['temp_ID', 'date', 'strike_price', 'spot_price', 'forward_price', 'vix',
#        'div_yield', 'risk_free', 'time_to_maturity_OPT', 'moneyness',
#        'option_price', 'bidask_spread', 'effective_spread', 'vwap', 'volume',
#        'open_interest', 'impl_volatility', 'delta', 'gamma', 'vega', 'theta',
#        'rho', 'vanna', 'charm', 'vomma', 'zomma', 'color', 'dvega_dtime',
#        'return', 'his_volatility', 'realised_skewness', 'realised_kurtosis',
#        'model_free_iv', 'model_free_skew', 'model_free_kurt', 'rv_iv',
#        'rv_mfvol', 'rskew_mfskew', 'rkurt_mfkurt', 'call_payoff'],
#       dtype='object')

# %%
# Monthly panels
calls['date'] = pd.to_datetime(calls['date'])
calls['month'] = calls['date'].dt.to_period('M').dt.to_timestamp().astype('int64') // 10**9

# Unique identifier based on strike and maturity to respect parity conditions
calls['unique_id'] = (calls['strike_price'].astype(str) + '_' + 
                      calls['time_to_maturity_OPT'].astype(str))

# Converting to a numeric ID
unique_ids = np.unique(calls['unique_id'])
ID_map = dict(zip(unique_ids, np.arange(1, len(unique_ids) + 1)))
calls['unique_id'] = calls['unique_id'].apply(lambda x: ID_map[x])

# MultiIndex with ID and monthly panel
calls.set_index(['unique_id', 'month'], inplace=True)

# Splitting into testing and training
max_year = calls['date'].max().year
train_data = calls[calls['date'].dt.year < (max_year - 2)]
test_data = calls[calls['date'].dt.year >= (max_year - 2)]

# Training data
X_train = train_data.drop(['call_payoff', 'date', 'temp_ID'], axis=1).select_dtypes(include=[np.number])
y_train = train_data['call_payoff']

# Testing data (stable economic conditions)
X_test = test_data.drop(['call_payoff', 'date', 'temp_ID'], axis=1).select_dtypes(include=[np.number])
y_test = test_data['call_payoff']

# Normalisation
means = X_train.mean()
stds = X_train.std()
X_train_scaled = (X_train - means) / stds
X_train = pd.DataFrame(X_train_scaled, index=X_train.index, columns=X_train.columns)
X_test_scaled = (X_test - means) / stds
X_test = pd.DataFrame(X_test_scaled, index=X_test.index, columns=X_test.columns)

# Panel indices
train_indices = np.array([X_train.index.get_level_values(0), X_train.index.get_level_values(1)]).T
test_indices = np.array([X_test.index.get_level_values(0), X_test.index.get_level_values(1)]).T

# Fitting IPCA with intercept (unrestricted model)
ipca = InstrumentedPCA(n_factors=5, intercept=True) # unstable, might need to set max_iter depending on CPU model
ipca.fit(X=X_train, y=y_train, indices=train_indices)
Gamma, Factors = ipca.get_factors(label_ind=True)
# Step 6988 - Aggregate Update: 28.13428222566418
# Step 6989 - Aggregate Update: 8.64404146557604
# Step 6990 - Aggregate Update: 39.08188534825335
# Step 6991 - Aggregate Update: 34.12291260775067
# Step 6992 - Aggregate Update: 32.318948877097355
# Step 6993 - Aggregate Update: 32.540538062577
# Step 6994 - Aggregate Update: 33.41611626783282
# Step 6995 - Aggregate Update: 18.841511242130064
# Step 6996 - Aggregate Update: 21.394051245624247
# Step 6997 - Aggregate Update: 46.12648527426985
# Step 6998 - Aggregate Update: 103.3956491510035
# Step 6999 - Aggregate Update: 120.49884560801311
# Step 7000 - Aggregate Update: 45.65496735695202
# Step 7001 - Aggregate Update: 38.453586177729875
# -- Convergence Reached --

# %% [markdown]
# ## Evaluation Metrics

# %%
# In-sample R²
r2_train = ipca.score(X=X_train, y=y_train, indices=train_indices)

# Out of sample predictions
y_test_pred = ipca.predictOOS(X=X_test, y = y_test, mean_factor=True)
# R² Pred
r2_pred = r2_score(y_test, y_test_pred)

print(f"R² (train): {r2_train}")
print(f"R² Pred (test): {r2_pred}")
# Out:
# R² (train): 0.7102538026444782
# R² Pred (test): 0.5376572762172972

# %%
# Residuals for the test set
residuals_test = y_test - y_test_pred
y_train_pred = ipca.predictOOS(X=X_train, y = y_train, mean_factor=True)

# Residuals for the training set
residuals_train = y_train - y_train_pred

# %%
# y_test vs y_test_pred
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_test_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='black', linestyle='--')
plt.xlabel('Test Set True Values')
plt.ylabel('Predicted Values')
plt.title('Test Set True vs Predicted Values - IPCA5 Calls')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Wald Test for Coefficients Significance

# %%
Gamma = Gamma.values  # numpy array

# Covariance matrix of the factor loadings across the characteristics
Gamma_cov = np.cov(Gamma.T)

# Wald Test Function
def wald_test_matrix(Gamma, Gamma_cov):
    results = []
    num_loadings = Gamma.shape[0]  # 37 characteristics
    num_factors = Gamma.shape[1]  # 21 factors (20 + intercept)

    for i in range(num_loadings):
        Gamma_i = Gamma[i, :]
        wald_stat = np.dot(np.dot(Gamma_i.T, np.linalg.inv(Gamma_cov)), Gamma_i)
        df = num_factors
        p_value = 1 - chi2.cdf(wald_stat, df)
        results.append((wald_stat, p_value, "Significant" if p_value < 0.05 else "Not Significant"))

    return results

# Running the Wald test
wald_results = wald_test_matrix(Gamma, Gamma_cov)
for i, (wald_stat, p_value, significance) in enumerate(wald_results):
    print(f"Characteristic {i+1}: Wald Statistic: {wald_stat:.4f}, P-value: {p_value:.4f}, Result: {significance}")
# Out:
# Characteristic 1: Wald Statistic: 0.2461, P-value: 0.9997, Result: Not Significant
# Characteristic 2: Wald Statistic: 33.5964, P-value: 0.0000, Result: Significant
# Characteristic 3: Wald Statistic: 0.0014, P-value: 1.0000, Result: Not Significant
# Characteristic 4: Wald Statistic: 5.4764, P-value: 0.4843, Result: Not Significant
# Characteristic 5: Wald Statistic: 0.0014, P-value: 1.0000, Result: Not Significant
# Characteristic 6: Wald Statistic: 0.0004, P-value: 1.0000, Result: Not Significant
# Characteristic 7: Wald Statistic: 0.5241, P-value: 0.9975, Result: Not Significant
# Characteristic 8: Wald Statistic: 0.0057, P-value: 1.0000, Result: Not Significant
# Characteristic 9: Wald Statistic: 25.6386, P-value: 0.0003, Result: Significant
# Characteristic 10: Wald Statistic: 0.1186, P-value: 1.0000, Result: Not Significant
# Characteristic 11: Wald Statistic: 0.1191, P-value: 1.0000, Result: Not Significant
# Characteristic 12: Wald Statistic: 30.9443, P-value: 0.0000, Result: Significant
# Characteristic 13: Wald Statistic: 0.0042, P-value: 1.0000, Result: Not Significant
# Characteristic 14: Wald Statistic: 0.0031, P-value: 1.0000, Result: Not Significant
# Characteristic 15: Wald Statistic: 8.1043, P-value: 0.2306, Result: Not Significant
# Characteristic 16: Wald Statistic: 0.6298, P-value: 0.9959, Result: Not Significant
# Characteristic 17: Wald Statistic: 0.0351, P-value: 1.0000, Result: Not Significant
# Characteristic 18: Wald Statistic: 9.6545, P-value: 0.1400, Result: Not Significant
# Characteristic 19: Wald Statistic: 0.0250, P-value: 1.0000, Result: Not Significant
# Characteristic 20: Wald Statistic: 0.1274, P-value: 1.0000, Result: Not Significant
# Characteristic 21: Wald Statistic: 0.0250, P-value: 1.0000, Result: Not Significant
# Characteristic 22: Wald Statistic: 0.0103, P-value: 1.0000, Result: Not Significant
# Characteristic 23: Wald Statistic: 0.0847, P-value: 1.0000, Result: Not Significant
# Characteristic 24: Wald Statistic: 0.0533, P-value: 1.0000, Result: Not Significant
# Characteristic 25: Wald Statistic: 0.0085, P-value: 1.0000, Result: Not Significant
# Characteristic 26: Wald Statistic: 0.0022, P-value: 1.0000, Result: Not Significant
# Characteristic 27: Wald Statistic: 0.0163, P-value: 1.0000, Result: Not Significant
# Characteristic 28: Wald Statistic: 2.2561, P-value: 0.8947, Result: Not Significant
# Characteristic 29: Wald Statistic: 5.0716, P-value: 0.5347, Result: Not Significant
# Characteristic 30: Wald Statistic: 2.9997, P-value: 0.8089, Result: Not Significant
# Characteristic 31: Wald Statistic: 18.6542, P-value: 0.0048, Result: Significant
# Characteristic 32: Wald Statistic: 14.8139, P-value: 0.0218, Result: Significant
# Characteristic 33: Wald Statistic: 13.0623, P-value: 0.0421, Result: Significant
# Characteristic 34: Wald Statistic: 11.1527, P-value: 0.0838, Result: Not Significant
# Characteristic 35: Wald Statistic: 18.6629, P-value: 0.0048, Result: Significant
# Characteristic 36: Wald Statistic: 15.1417, P-value: 0.0192, Result: Significant
# Characteristic 37: Wald Statistic: 13.0229, P-value: 0.0427, Result: Significant

# %% [markdown]
# ### Confidence Intervals for Coefficients Significance

# %%
# Variance of residuals
residual_variance = np.var(residuals_train, ddof=1)  # sample variance

# Matrix to store the standard errors
std_errors_gamma = np.zeros(Gamma.shape)
for i in range(Gamma.shape[0]):  # For each characteristic (row in Gamma)
    for j in range(Gamma.shape[1]):  # For each factor (column in Gamma)
        std_errors_gamma[i, j] = np.sqrt(residual_variance / np.sum(X_train.iloc[:, j] ** 2))

# Confidence level alpha 5%
z_value = 1.96

# Confidence intervals for each loading
lower_bounds_gamma = Gamma - z_value * std_errors_gamma
upper_bounds_gamma = Gamma + z_value * std_errors_gamma

# Checking significance based on whether the CI includes zero
significant_loadings = (lower_bounds_gamma > 0) | (upper_bounds_gamma < 0)

# Arrays
significant_loadings = significant_loadings.values if isinstance(significant_loadings, pd.DataFrame) else significant_loadings
lower_bounds_gamma = lower_bounds_gamma.values if isinstance(lower_bounds_gamma, pd.DataFrame) else lower_bounds_gamma
upper_bounds_gamma = upper_bounds_gamma.values if isinstance(upper_bounds_gamma, pd.DataFrame) else upper_bounds_gamma

# Print check
for i in range(Gamma.shape[0]):  # For each characteristic
    for j in range(Gamma.shape[1]):  # For each factor
        is_significant = "Significant" if significant_loadings[i, j] else "Not Significant"
        print(f"Characteristic {i+1}, Factor {j+1}: CI = [{lower_bounds_gamma[i, j]:.4f}, {upper_bounds_gamma[i, j]:.4f}], {is_significant}")
# Out:
# Characteristic 1, Factor 1: CI = [-0.1149, 0.1171], Not Significant
# Characteristic 1, Factor 2: CI = [-0.1183, 0.1137], Not Significant
# Characteristic 1, Factor 3: CI = [-0.1372, 0.0948], Not Significant
# Characteristic 1, Factor 4: CI = [-0.1856, 0.0464], Not Significant
# Characteristic 1, Factor 5: CI = [-0.1418, 0.0902], Not Significant
# Characteristic 1, Factor 6: CI = [-0.6485, -0.4165], Significant
# Characteristic 2, Factor 1: CI = [-0.0960, 0.1360], Not Significant
# Characteristic 2, Factor 2: CI = [-0.1267, 0.1053], Not Significant
# Characteristic 2, Factor 3: CI = [0.6507, 0.8827], Significant
# Characteristic 2, Factor 4: CI = [-0.3077, -0.0757], Significant
# Characteristic 2, Factor 5: CI = [0.3664, 0.5984], Significant
# Characteristic 2, Factor 6: CI = [13.4110, 13.6430], Significant
# Characteristic 3, Factor 1: CI = [-0.1160, 0.1160], Not Significant
# Characteristic 3, Factor 2: CI = [-0.1163, 0.1157], Not Significant
# Characteristic 3, Factor 3: CI = [-0.1184, 0.1136], Not Significant
# Characteristic 3, Factor 4: CI = [-0.1200, 0.1120], Not Significant
# Characteristic 3, Factor 5: CI = [-0.1197, 0.1123], Not Significant
# Characteristic 3, Factor 6: CI = [-0.2613, -0.0293], Significant
# Characteristic 4, Factor 1: CI = [-0.1150, 0.1170], Not Significant
# Characteristic 4, Factor 2: CI = [-0.1426, 0.0894], Not Significant
# Characteristic 4, Factor 3: CI = [-0.1125, 0.1195], Not Significant
# Characteristic 4, Factor 4: CI = [-0.4462, -0.2142], Significant
# Characteristic 4, Factor 5: CI = [-0.2649, -0.0329], Significant
# Characteristic 4, Factor 6: CI = [4.5278, 4.7598], Significant
# Characteristic 5, Factor 1: CI = [-0.1157, 0.1163], Not Significant
# Characteristic 5, Factor 2: CI = [-0.1160, 0.1160], Not Significant
# Characteristic 5, Factor 3: CI = [-0.1162, 0.1158], Not Significant
# Characteristic 5, Factor 4: CI = [-0.1215, 0.1105], Not Significant
# Characteristic 5, Factor 5: CI = [-0.1181, 0.1139], Not Significant
# Characteristic 5, Factor 6: CI = [-0.1997, 0.0323], Not Significant
# Characteristic 6, Factor 1: CI = [-0.1160, 0.1160], Not Significant
# Characteristic 6, Factor 2: CI = [-0.1161, 0.1159], Not Significant
# Characteristic 6, Factor 3: CI = [-0.1168, 0.1152], Not Significant
# Characteristic 6, Factor 4: CI = [-0.1185, 0.1135], Not Significant
# Characteristic 6, Factor 5: CI = [-0.1172, 0.1148], Not Significant
# Characteristic 6, Factor 6: CI = [-0.2408, -0.0089], Significant
# Characteristic 7, Factor 1: CI = [-0.1156, 0.1164], Not Significant
# Characteristic 7, Factor 2: CI = [-0.1174, 0.1146], Not Significant
# Characteristic 7, Factor 3: CI = [-0.1434, 0.0886], Not Significant
# Characteristic 7, Factor 4: CI = [-0.1583, 0.0737], Not Significant
# Characteristic 7, Factor 5: CI = [-0.1882, 0.0438], Not Significant
# Characteristic 7, Factor 6: CI = [6.6685, 6.9005], Significant
# Characteristic 8, Factor 1: CI = [-0.1158, 0.1162], Not Significant
# Characteristic 8, Factor 2: CI = [-0.1167, 0.1153], Not Significant
# Characteristic 8, Factor 3: CI = [-0.1211, 0.1109], Not Significant
# Characteristic 8, Factor 4: CI = [-0.1219, 0.1101], Not Significant
# Characteristic 8, Factor 5: CI = [-0.1233, 0.1087], Not Significant
# Characteristic 8, Factor 6: CI = [0.4023, 0.6343], Significant
# Characteristic 9, Factor 1: CI = [0.4519, 0.6839], Significant
# Characteristic 9, Factor 2: CI = [-0.4698, -0.2378], Significant
# Characteristic 9, Factor 3: CI = [-0.0075, 0.2245], Not Significant
# Characteristic 9, Factor 4: CI = [-0.1321, 0.0999], Not Significant
# Characteristic 9, Factor 5: CI = [-0.1913, 0.0407], Not Significant
# Characteristic 9, Factor 6: CI = [40.5895, 40.8215], Significant
# Characteristic 10, Factor 1: CI = [-0.1155, 0.1165], Not Significant
# Characteristic 10, Factor 2: CI = [-0.1188, 0.1131], Not Significant
# Characteristic 10, Factor 3: CI = [-0.1305, 0.1015], Not Significant
# Characteristic 10, Factor 4: CI = [-0.1226, 0.1094], Not Significant
# Characteristic 10, Factor 5: CI = [-0.1564, 0.0756], Not Significant
# Characteristic 10, Factor 6: CI = [2.9701, 3.2021], Significant
# Characteristic 11, Factor 1: CI = [-0.1164, 0.1156], Not Significant
# Characteristic 11, Factor 2: CI = [-0.1147, 0.1173], Not Significant
# Characteristic 11, Factor 3: CI = [-0.1030, 0.1290], Not Significant
# Characteristic 11, Factor 4: CI = [-0.0980, 0.1340], Not Significant
# Characteristic 11, Factor 5: CI = [-0.0930, 0.1390], Not Significant
# Characteristic 11, Factor 6: CI = [-4.0174, -3.7854], Significant
# Characteristic 12, Factor 1: CI = [-0.6846, -0.4526], Significant
# Characteristic 12, Factor 2: CI = [0.2408, 0.4728], Significant
# Characteristic 12, Factor 3: CI = [-0.2019, 0.0301], Not Significant
# Characteristic 12, Factor 4: CI = [-0.0879, 0.1441], Not Significant
# Characteristic 12, Factor 5: CI = [-0.0088, 0.2232], Not Significant
# Characteristic 12, Factor 6: CI = [51.4292, 51.6612], Significant
# Characteristic 13, Factor 1: CI = [-0.1160, 0.1160], Not Significant
# Characteristic 13, Factor 2: CI = [-0.1159, 0.1161], Not Significant
# Characteristic 13, Factor 3: CI = [-0.1142, 0.1178], Not Significant
# Characteristic 13, Factor 4: CI = [-0.1119, 0.1201], Not Significant
# Characteristic 13, Factor 5: CI = [-0.1113, 0.1206], Not Significant
# Characteristic 13, Factor 6: CI = [-0.8234, -0.5914], Significant
# Characteristic 14, Factor 1: CI = [-0.1160, 0.1160], Not Significant
# Characteristic 14, Factor 2: CI = [-0.1157, 0.1163], Not Significant
# Characteristic 14, Factor 3: CI = [-0.1122, 0.1198], Not Significant
# Characteristic 14, Factor 4: CI = [-0.1107, 0.1213], Not Significant
# Characteristic 14, Factor 5: CI = [-0.1105, 0.1215], Not Significant
# Characteristic 14, Factor 6: CI = [0.1887, 0.4207], Significant
# Characteristic 15, Factor 1: CI = [-0.2203, 0.0116], Not Significant
# Characteristic 15, Factor 2: CI = [-0.2100, 0.0220], Not Significant
# Characteristic 15, Factor 3: CI = [-0.2800, -0.0480], Significant
# Characteristic 15, Factor 4: CI = [-0.2522, -0.0202], Significant
# Characteristic 15, Factor 5: CI = [0.2306, 0.4626], Significant
# Characteristic 15, Factor 6: CI = [-7.0635, -6.8316], Significant
# Characteristic 16, Factor 1: CI = [-0.1168, 0.1152], Not Significant
# Characteristic 16, Factor 2: CI = [-0.1122, 0.1198], Not Significant
# Characteristic 16, Factor 3: CI = [-0.0755, 0.1565], Not Significant
# Characteristic 16, Factor 4: CI = [-0.0633, 0.1687], Not Significant
# Characteristic 16, Factor 5: CI = [-0.0247, 0.2073], Not Significant
# Characteristic 16, Factor 6: CI = [-5.7736, -5.5416], Significant
# Characteristic 17, Factor 1: CI = [-0.1161, 0.1159], Not Significant
# Characteristic 17, Factor 2: CI = [-0.1167, 0.1153], Not Significant
# Characteristic 17, Factor 3: CI = [-0.1248, 0.1072], Not Significant
# Characteristic 17, Factor 4: CI = [-0.1381, 0.0939], Not Significant
# Characteristic 17, Factor 5: CI = [-0.1335, 0.0985], Not Significant
# Characteristic 17, Factor 6: CI = [0.4663, 0.6983], Significant
# Characteristic 18, Factor 1: CI = [-0.1214, 0.1106], Not Significant
# Characteristic 18, Factor 2: CI = [-0.1008, 0.1312], Not Significant
# Characteristic 18, Factor 3: CI = [0.0087, 0.2407], Significant
# Characteristic 18, Factor 4: CI = [-0.0415, 0.1905], Not Significant
# Characteristic 18, Factor 5: CI = [0.0792, 0.3112], Significant
# Characteristic 18, Factor 6: CI = [-37.8775, -37.6455], Significant
# Characteristic 19, Factor 1: CI = [-0.1159, 0.1161], Not Significant
# Characteristic 19, Factor 2: CI = [-0.1170, 0.1150], Not Significant
# Characteristic 19, Factor 3: CI = [-0.1237, 0.1083], Not Significant
# Characteristic 19, Factor 4: CI = [-0.1338, 0.0982], Not Significant
# Characteristic 19, Factor 5: CI = [-0.1285, 0.1034], Not Significant
# Characteristic 19, Factor 6: CI = [0.7526, 0.9846], Significant
# Characteristic 20, Factor 1: CI = [-0.1156, 0.1164], Not Significant
# Characteristic 20, Factor 2: CI = [-0.1180, 0.1140], Not Significant
# Characteristic 20, Factor 3: CI = [-0.1381, 0.0939], Not Significant
# Characteristic 20, Factor 4: CI = [-0.1539, 0.0781], Not Significant
# Characteristic 20, Factor 5: CI = [-0.1551, 0.0769], Not Significant
# Characteristic 20, Factor 6: CI = [-0.2683, -0.0363], Significant
# Characteristic 21, Factor 1: CI = [-0.1159, 0.1161], Not Significant
# Characteristic 21, Factor 2: CI = [-0.1158, 0.1162], Not Significant
# Characteristic 21, Factor 3: CI = [-0.1077, 0.1243], Not Significant
# Characteristic 21, Factor 4: CI = [-0.1008, 0.1312], Not Significant
# Characteristic 21, Factor 5: CI = [-0.0993, 0.1327], Not Significant
# Characteristic 21, Factor 6: CI = [-0.9325, -0.7005], Significant
# Characteristic 22, Factor 1: CI = [-0.1157, 0.1163], Not Significant
# Characteristic 22, Factor 2: CI = [-0.1169, 0.1151], Not Significant
# Characteristic 22, Factor 3: CI = [-0.1209, 0.1111], Not Significant
# Characteristic 22, Factor 4: CI = [-0.1227, 0.1093], Not Significant
# Characteristic 22, Factor 5: CI = [-0.1285, 0.1035], Not Significant
# Characteristic 22, Factor 6: CI = [0.5282, 0.7602], Significant
# Characteristic 23, Factor 1: CI = [-0.1160, 0.1160], Not Significant
# Characteristic 23, Factor 2: CI = [-0.1168, 0.1152], Not Significant
# Characteristic 23, Factor 3: CI = [-0.1337, 0.0983], Not Significant
# Characteristic 23, Factor 4: CI = [-0.1483, 0.0837], Not Significant
# Characteristic 23, Factor 5: CI = [-0.1462, 0.0858], Not Significant
# Characteristic 23, Factor 6: CI = [0.1426, 0.3746], Significant
# Characteristic 24, Factor 1: CI = [-0.1161, 0.1159], Not Significant
# Characteristic 24, Factor 2: CI = [-0.1154, 0.1166], Not Significant
# Characteristic 24, Factor 3: CI = [-0.1036, 0.1284], Not Significant
# Characteristic 24, Factor 4: CI = [-0.0970, 0.1350], Not Significant
# Characteristic 24, Factor 5: CI = [-0.0895, 0.1425], Not Significant
# Characteristic 24, Factor 6: CI = [-1.4174, -1.1854], Significant
# Characteristic 25, Factor 1: CI = [-0.1160, 0.1160], Not Significant
# Characteristic 25, Factor 2: CI = [-0.1159, 0.1161], Not Significant
# Characteristic 25, Factor 3: CI = [-0.1113, 0.1207], Not Significant
# Characteristic 25, Factor 4: CI = [-0.1082, 0.1238], Not Significant
# Characteristic 25, Factor 5: CI = [-0.1062, 0.1258], Not Significant
# Characteristic 25, Factor 6: CI = [-0.7171, -0.4851], Significant
# Characteristic 26, Factor 1: CI = [-0.1160, 0.1160], Not Significant
# Characteristic 26, Factor 2: CI = [-0.1158, 0.1162], Not Significant
# Characteristic 26, Factor 3: CI = [-0.1168, 0.1152], Not Significant
# Characteristic 26, Factor 4: CI = [-0.1124, 0.1196], Not Significant
# Characteristic 26, Factor 5: CI = [-0.1169, 0.1150], Not Significant
# Characteristic 26, Factor 6: CI = [0.4384, 0.6704], Significant
# Characteristic 27, Factor 1: CI = [-0.1162, 0.1158], Not Significant
# Characteristic 27, Factor 2: CI = [-0.1172, 0.1148], Not Significant
# Characteristic 27, Factor 3: CI = [-0.1258, 0.1062], Not Significant
# Characteristic 27, Factor 4: CI = [-0.1296, 0.1024], Not Significant
# Characteristic 27, Factor 5: CI = [-0.1283, 0.1037], Not Significant
# Characteristic 27, Factor 6: CI = [0.0499, 0.2819], Significant
# Characteristic 28, Factor 1: CI = [-0.0626, 0.1694], Not Significant
# Characteristic 28, Factor 2: CI = [-0.0691, 0.1629], Not Significant
# Characteristic 28, Factor 3: CI = [-0.0379, 0.1941], Not Significant
# Characteristic 28, Factor 4: CI = [-0.0527, 0.1793], Not Significant
# Characteristic 28, Factor 5: CI = [-0.3075, -0.0755], Significant
# Characteristic 28, Factor 6: CI = [3.7831, 4.0151], Significant
# Characteristic 29, Factor 1: CI = [-0.1162, 0.1158], Not Significant
# Characteristic 29, Factor 2: CI = [-0.1224, 0.1096], Not Significant
# Characteristic 29, Factor 3: CI = [-0.2789, -0.0469], Significant
# Characteristic 29, Factor 4: CI = [-0.3893, -0.1573], Significant
# Characteristic 29, Factor 5: CI = [-0.2305, 0.0015], Not Significant
# Characteristic 29, Factor 6: CI = [-10.7062, -10.4742], Significant
# Characteristic 30, Factor 1: CI = [-0.1135, 0.1185], Not Significant
# Characteristic 30, Factor 2: CI = [-0.1113, 0.1207], Not Significant
# Characteristic 30, Factor 3: CI = [-0.0929, 0.1391], Not Significant
# Characteristic 30, Factor 4: CI = [-0.0329, 0.1991], Not Significant
# Characteristic 30, Factor 5: CI = [0.0860, 0.3180], Significant
# Characteristic 30, Factor 6: CI = [-15.6511, -15.4192], Significant
# Characteristic 31, Factor 1: CI = [0.2662, 0.4981], Significant
# Characteristic 31, Factor 2: CI = [0.3245, 0.5565], Significant
# Characteristic 31, Factor 3: CI = [-0.3402, -0.1082], Significant
# Characteristic 31, Factor 4: CI = [-0.3153, -0.0833], Significant
# Characteristic 31, Factor 5: CI = [0.0981, 0.3301], Significant
# Characteristic 31, Factor 6: CI = [3.5326, 3.7646], Significant
# Characteristic 32, Factor 1: CI = [-0.2369, -0.0049], Significant
# Characteristic 32, Factor 2: CI = [-0.1386, 0.0934], Not Significant
# Characteristic 32, Factor 3: CI = [-0.0203, 0.2117], Not Significant
# Characteristic 32, Factor 4: CI = [-0.6689, -0.4369], Significant
# Characteristic 32, Factor 5: CI = [-0.2988, -0.0668], Significant
# Characteristic 32, Factor 6: CI = [-6.4129, -6.1809], Significant
# Characteristic 33, Factor 1: CI = [-0.1608, 0.0712], Not Significant
# Characteristic 33, Factor 2: CI = [-0.5251, -0.2931], Significant
# Characteristic 33, Factor 3: CI = [-0.4075, -0.1755], Significant
# Characteristic 33, Factor 4: CI = [-0.2221, 0.0099], Not Significant
# Characteristic 33, Factor 5: CI = [0.1065, 0.3385], Significant
# Characteristic 33, Factor 6: CI = [10.8002, 11.0322], Significant
# Characteristic 34, Factor 1: CI = [-0.2364, -0.0044], Significant
# Characteristic 34, Factor 2: CI = [-0.2221, 0.0099], Not Significant
# Characteristic 34, Factor 3: CI = [-0.2844, -0.0524], Significant
# Characteristic 34, Factor 4: CI = [-0.2414, -0.0095], Significant
# Characteristic 34, Factor 5: CI = [0.3188, 0.5508], Significant
# Characteristic 34, Factor 6: CI = [-8.5019, -8.2699], Significant
# Characteristic 35, Factor 1: CI = [0.2663, 0.4983], Significant
# Characteristic 35, Factor 2: CI = [0.3251, 0.5571], Significant
# Characteristic 35, Factor 3: CI = [-0.3361, -0.1041], Significant
# Characteristic 35, Factor 4: CI = [-0.3010, -0.0690], Significant
# Characteristic 35, Factor 5: CI = [0.1117, 0.3437], Significant
# Characteristic 35, Factor 6: CI = [4.7717, 5.0037], Significant
# Characteristic 36, Factor 1: CI = [-0.2370, -0.0050], Significant
# Characteristic 36, Factor 2: CI = [-0.1389, 0.0930], Not Significant
# Characteristic 36, Factor 3: CI = [-0.0235, 0.2085], Not Significant
# Characteristic 36, Factor 4: CI = [-0.6751, -0.4431], Significant
# Characteristic 36, Factor 5: CI = [-0.3058, -0.0738], Significant
# Characteristic 36, Factor 6: CI = [-6.2233, -5.9913], Significant
# Characteristic 37, Factor 1: CI = [-0.1607, 0.0713], Not Significant
# Characteristic 37, Factor 2: CI = [-0.5247, -0.2927], Significant
# Characteristic 37, Factor 3: CI = [-0.4041, -0.1722], Significant
# Characteristic 37, Factor 4: CI = [-0.2167, 0.0153], Not Significant
# Characteristic 37, Factor 5: CI = [0.1134, 0.3454], Significant
# Characteristic 37, Factor 6: CI = [10.6513, 10.8833], Significant

# %% [markdown]
# ### Scree Plot & Gamma-Factors Loadings

# %%
correlation_matrix = np.corrcoef(X_train.T)  # correlation between characteristics
eigenvalues, _ = np.linalg.eig(correlation_matrix)
sorted_eigenvalues = np.sort(eigenvalues)[::-1]

# Scree plot
plt.plot(sorted_eigenvalues)
plt.title("Scree Plot - IPCA Calls")
plt.xlabel("Factors")
plt.ylabel("Eigenvalues")
plt.show()

# %%
# Gamma loadings for each factor - IPCA5 Calls
for factor in Gamma.columns:
    plt.figure(figsize=(14, 8))
    plt.bar(Gamma.index, Gamma[factor], color='skyblue', edgecolor='black')
    plt.axhline(0, color='black', linewidth=1)
    plt.title(f'Gamma Loadings for Factor {factor} - IPCA5 Calls', fontsize=16)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Covid Test Set
# - Covid testing set from 01/01/2020 to 28/02/2023
# - Features are engineered following the same process executed in the notebook "SPX_Preprocessing_DASK"

# %%
covid_calls = pd.read_csv('IPCA_Calls_Stress_Test.csv')
covid_calls.drop(['put_payoff'], axis=1, inplace=True)
covid_calls.dropna(inplace=True)
covid_calls.rename(columns={'Unnamed: 0': 'temp_ID'}, inplace=True)
covid_calls.drop(['option_type', 'best_ask', 'best_bid', 'best_bid_size', 'best_ask_size', 'expiration'], axis=1, inplace=True)
covid_calls.columns
# Out:
# Index(['temp_ID', 'date', 'strike_price', 'spot_price', 'forward_price', 'vix',
#        'div_yield', 'risk_free', 'time_to_maturity_OPT', 'moneyness',
#        'option_price', 'bidask_spread', 'effective_spread', 'vwap', 'volume',
#        'open_interest', 'impl_volatility', 'delta', 'gamma', 'vega', 'theta',
#        'rho', 'vanna', 'charm', 'vomma', 'zomma', 'color', 'dvega_dtime',
#        'return', 'his_volatility', 'realised_skewness', 'realised_kurtosis',
#        'model_free_iv', 'model_free_skew', 'model_free_kurt', 'rv_iv',
#        'rv_mfvol', 'rskew_mfskew', 'rkurt_mfkurt', 'call_payoff'],
#       dtype='object')

# %%
# Monthly panels
covid_calls['date'] = pd.to_datetime(covid_calls['date'])
covid_calls['month'] = covid_calls['date'].dt.to_period('M').dt.to_timestamp().astype('int64') // 10**9

# Unique identifier based on strike and maturity to respect parity conditions
covid_calls['unique_id'] = (covid_calls['strike_price'].astype(str) + '_' + 
                      covid_calls['time_to_maturity_OPT'].astype(str))

# Converting to a numeric ID
unique_ids = np.unique(covid_calls['unique_id'])
ID_map = dict(zip(unique_ids, np.arange(1, len(unique_ids) + 1)))
covid_calls['unique_id'] = covid_calls['unique_id'].apply(lambda x: ID_map[x])
covid_calls.set_index(['unique_id', 'month'], inplace=True)

# Covid testing set
X_test_covid = covid_calls.drop(['call_payoff', 'date', 'temp_ID'], axis=1).select_dtypes(include=[np.number])
y_test_covid = covid_calls['call_payoff']

# Normalisation
X_test_scaled = (X_test_covid - means) / stds
X_test_covid = pd.DataFrame(X_test_scaled, index=X_test_covid.index, columns=X_test_covid.columns)

# %%
covid_test_indices = np.array([X_test_covid.index.get_level_values(0), X_test_covid.index.get_level_values(1)]).T

# Out of sample predictions on Covid set
y_test_pred_covid = ipca.predictOOS(X=X_test_covid, y=y_test_covid, indices=covid_test_indices, mean_factor=True)
r2_pred = r2_score(y_test_covid, y_test_pred_covid)
print(f"R² Pred (test): {r2_pred}")
# Out:
# R² Pred (test): 0.1531783293825062

# %%
# y_test_covid vs y_test_pred_covid
plt.figure(figsize=(10, 6))
plt.scatter(y_test_covid, y_test_pred_covid, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='black', linestyle='--')
plt.xlabel('Covid Set True Values')
plt.ylabel('Predicted Values')
plt.title('Covid Set True vs Predicted Values - IPCA5 Calls')  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Saving intermediate datasets for prediction modelling

# %%
# Saving test data IPCA 20 Factors Calls
test_data[['date', 'call_payoff', 'spot_price', 'strike_price', 'time_to_maturity_OPT', 'risk_free', 'impl_volatility']].to_csv('Test_Calls5.csv')

# %%
# Merging real test Covid and prediction values
y_test = y_test.to_numpy()
df = pd.DataFrame({'True': y_test, 'Predicted': y_test_pred})
df.to_csv('IPCA_Calls_Predictions_Test5.csv')

# %%
# Saving Covid test data IPCA 20 Factors Calls
covid_calls[['date', 'call_payoff', 'spot_price', 'strike_price', 'time_to_maturity_OPT', 'risk_free', 'impl_volatility']].to_csv('Covid_Calls5.csv')

# %%
# Merging real Covid test and prediction values
y_test_covid = y_test_covid.to_numpy()
df = pd.DataFrame({'True': y_test_covid, 'Predicted': y_test_pred_covid})
df.to_csv('IPCA_Calls_Predictions_Covid5.csv')
